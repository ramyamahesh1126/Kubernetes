# %% [markdown]
# <a href="https://colab.research.google.com/github/ramyamahesh1126/Kubernetes/blob/master/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

#Data Set
X = np.array([[5,3],
    [3,7],
    [2,6],
    [5,8],
    [6,6],
    [5,5],
    [12,8],
    [10,6],
    [8,4],
    [7,3],
    [5,2],
    [2,2],])

import matplotlib.pyplot as plt

labels = range(1, 13)
plt.figure(figsize=(10, 7))
plt.subplots_adjust(bottom=0.1)
plt.scatter(X[:,0],X[:,1], label='True Position')

for label, x, y in zip(labels, X[:, 0], X[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-3, 3),
        textcoords='offset points', ha='right', va='bottom')
plt.show()


from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

#Single_linkage
linked = linkage(X, 'single')

labelList = range(1, 13)

plt.figure(figsize=(10, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()

#Complete linkage
linked = linkage(X, 'complete')

labelList = range(1, 13)

plt.figure(figsize=(10, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()

#Average linkage
linked = linkage(X, 'average')

labelList = range(1, 13)

plt.figure(figsize=(10, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()
